# %%
import spacy

# %%
nlp_el = spacy.load("./output_lt_2m_model/nlp")

text = "barack obama"


doc = nlp_el(text)
for ent in doc.ents:
    print(ent.text, ent.label_, ent.kb_id_)
# Out:
# barack obama PERSON NIL
